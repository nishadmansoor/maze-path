# %%
import pandas as pd
import sklearn
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, accuracy_score

# %%
# Load the dataset
data = pd.read_csv('dataset.csv')
data.head()
# Out:
#    size   density  bfs_cost  bfs_time  ucs_cost  ucs_time  greedy_cost  \
# 0    10  0.319344        63  0.000043        63  0.000068           63
# 1    20  0.339263       291  0.000201       261  0.000305          309
# 2    20  0.253491       190  0.000223       158  0.000325          214
# 3    10  0.277651        63  0.000052        58  0.000065          120
# 4    10  0.267407        86  0.000054        86  0.000074          109
#
#    greedy_time  astar_cost  astar_time  mcts_cost  mcts_time best_algorithm
# 0     0.000023          63    0.000061       6871   0.204658         greedy
# 1     0.000097         261    0.000328      63140   4.720208            ucs
# 2     0.000065         158    0.000347      26104   1.490501            ucs
# 3     0.000036          58    0.000061       1816   0.167704          astar
# 4     0.000027          86    0.000067       2477   0.437705            bfs
